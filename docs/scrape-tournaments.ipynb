# %%
from bridgelib.base import Hand, Deal
from bridgelib.constants import *
from bridgelib.play import dds_solver, DDSResult, LiveResult
from bridgelib.scrape import scrape_ACBL_tournament, scrape_page, write_one_tournament
from bridgelib.score import score_contract, reverse_score, score_array
from bridgelib.bidding import Bidding, PassStrategy
from bridgelib.GIB import find_bid, GIBStrategy
from bridgelib.helpers import array_from_solver_out
from bridgelib.data import gen_dds, read_dds, read_results_file

import numpy as np
import time

# %%
for _ in range(100):
    write_one_tournament()
# Out:
# Scraping /event/NABC141/2802/1/summary
# Scrapped a total of 5 sections
# Analzing 39 boards
#      Writing to file NABC141_2802_1_summary.pkl
# Scraping /event/NABC141/2801/1/summary
# Scrapped a total of 3 sections
# Analzing 32 boards
#      Writing to file NABC141_2801_1_summary.pkl
# Scraping /event/NABC141/28I5/1/summary
# Scrapped a total of 1 sections
# Analzing 24 boards
#      Writing to file NABC141_28I5_1_summary.pkl
# Scraping /event/NABC141/28I1/1/summary
# Scrapped a total of 1 sections
# Analzing 32 boards
#      Writing to file NABC141_28I1_1_summary.pkl
# Scraping /event/NABC141/28I2/1/summary
# Scrapped a total of 1 sections
# Analzing 24 boards
#      Writing to file NABC141_28I2_1_summary.pkl
# Scraping /event/NABC141/SS7/1/summary
# Scrapped a total of 2 sections
# Analzing 26 boards
#      Writing to file NABC141_SS7_1_summary.pkl
# Scraping /event/NABC141/SS5/6/summary
# Scrapped a total of 2 sections
# Analzing 27 boards
#      Writing to file NABC141_SS5_6_summary.pkl
# Scraping /event/NABC141/OPPR/2/summary
# Scrapped a total of 10 sections
# Analzing 26 boards
#      Writing to file NABC141_OPPR_2_summary.pkl
# Scraping /event/NABC141/2702/2/summary
# Scrapped a total of 2 sections
# Analzing 33 boards
#      Writing to file NABC141_2702_2_summary.pkl
# Scraping /event/NABC141/WMPR/2/summary
# Scrapped a total of 3 sections
# Analzing 26 boards
#      Writing to file NABC141_WMPR_2_summary.pkl
# Scraping /event/NABC141/27I3/1/summary
# Scrapped a total of 2 sections
# Analzing 30 boards
#      Writing to file NABC141_27I3_1_summary.pkl
# Scraping /event/NABC141/27I4/1/summary
# Scrapped a total of 1 sections
# Analzing 23 boards
#      Writing to file NABC141_27I4_1_summary.pkl
# Scraping /event/NABC141/27I5/1/summary
# Scrapped a total of 1 sections
# Analzing 24 boards
#      Writing to file NABC141_27I5_1_summary.pkl
# Scraping /event/NABC141/27I6/1/summary
# Scrapped a total of 1 sections
# Analzing 0 boards
# Scraping /event/NABC141/27I1/1/summary
# Scrapped a total of 2 sections
# Analzing 30 boards
#      Writing to file NABC141_27I1_1_summary.pkl
# Scraping /event/NABC141/27I2/1/summary
# Scrapped a total of 1 sections
# Analzing 24 boards
#      Writing to file NABC141_27I2_1_summary.pkl
# Scraping /event/NABC141/REDR/1/summary
# Scrapped a total of 6 sections
# Analzing 26 boards
#      Writing to file NABC141_REDR_1_summary.pkl
# Scraping /event/NABC141/OPPR/1/summary
# Scrapped a total of 10 sections
# Analzing 26 boards
#      Writing to file NABC141_OPPR_1_summary.pkl
# Scraping /event/NABC141/2701/1/summary
# Scrapped a total of 3 sections
# Analzing 26 boards
#      Writing to file NABC141_2701_1_summary.pkl
# Scraping /event/NABC141/SS6/1/summary
# Scrapped a total of 1 sections
# Analzing 36 boards
#      Writing to file NABC141_SS6_1_summary.pkl
# Scraping /event/NABC141/WMPR/1/summary
# Scrapped a total of 3 sections
# Analzing 26 boards
#      Writing to file NABC141_WMPR_1_summary.pkl
# Scraping /event/NABC141/MIXD/4/summary
# Scrapped a total of 7 sections
# Analzing 26 boards
#      Writing to file NABC141_MIXD_4_summary.pkl
# Scraping /event/NABC141/SS4/3/summary
# Scrapped a total of 2 sections
# Analzing 27 boards
#      Writing to file NABC141_SS4_3_summary.pkl
# Scraping /event/NABC141/MIXD/3/summary
# Scrapped a total of 7 sections
# Analzing 26 boards
#      Writing to file NABC141_MIXD_3_summary.pkl
# Scraping /event/NABC141/SS5/3/summary
# Scrapped a total of 2 sections
# Analzing 30 boards
#      Writing to file NABC141_SS5_3_summary.pkl
# Scraping /event/NABC141/2602/2/summary
# Scrapped a total of 4 sections
# Analzing 28 boards
#      Writing to file NABC141_2602_2_summary.pkl
# Scraping /event/NABC141/2601/2/summary
# Scrapped a total of 4 sections
# Analzing 28 boards
#      Writing to file NABC141_2601_2_summary.pkl
# Scraping /event/NABC141/2603/2/summary
# Scrapped a total of 4 sections
# Analzing 33 boards
#      Writing to file NABC141_2603_2_summary.pkl
# Scraping /event/NABC141/2602/1/summary
# Scrapped a total of 4 sections
# Analzing 28 boards
#      Writing to file NABC141_2602_1_summary.pkl
# Scraping /event/NABC141/2604/1/summary
# Scrapped a total of 1 sections
# Analzing 0 boards
# Scraping /event/NABC141/2605/1/summary
# Scrapped a total of 1 sections
# Analzing 0 boards
# Scraping /event/NABC141/2601/1/summary
# Scrapped a total of 4 sections
# Analzing 28 boards
#      Writing to file NABC141_2601_1_summary.pkl
# Scraping /event/NABC141/26I5/1/summary
# Scrapped a total of 1 sections
# Analzing 24 boards
#      Writing to file NABC141_26I5_1_summary.pkl
# Scraping /event/NABC141/2603/1/summary
# Scrapped a total of 4 sections
# Analzing 33 boards
#      Writing to file NABC141_2603_1_summary.pkl
# Scraping /event/NABC141/26I1/1/summary
# Scrapped a total of 1 sections
# Analzing 26 boards
#      Writing to file NABC141_26I1_1_summary.pkl
# Scraping /event/NABC141/26I2/1/summary
# Scrapped a total of 1 sections
# Analzing 24 boards
#      Writing to file NABC141_26I2_1_summary.pkl
# Scraping /event/NABC141/MIXD/2/summary
# Scrapped a total of 13 sections
# Analzing 26 boards
#      Writing to file NABC141_MIXD_2_summary.pkl
# Scraping /event/NABC141/2502/2/summary
# Scrapped a total of 3 sections
# Analzing 27 boards
#      Writing to file NABC141_2502_2_summary.pkl
# Scraping /event/NABC141/2501/2/summary
# Scrapped a total of 3 sections
# Analzing 34 boards
#      Writing to file NABC141_2501_2_summary.pkl
# Scraping /event/NABC141/MIXD/1/summary
# Scrapped a total of 13 sections
# Analzing 26 boards
#      Writing to file NABC141_MIXD_1_summary.pkl
# Scraping /event/NABC141/25I3/1/summary
# Scrapped a total of 2 sections
# Analzing 33 boards
#      Writing to file NABC141_25I3_1_summary.pkl
# Scraping /event/NABC141/25I4/1/summary
# Scrapped a total of 1 sections
# Analzing 23 boards
#      Writing to file NABC141_25I4_1_summary.pkl
# Scraping /event/NABC141/2502/1/summary
# Scrapped a total of 3 sections
# Analzing 27 boards
#      Writing to file NABC141_2502_1_summary.pkl
# Scraping /event/NABC141/2501/1/summary
# Scrapped a total of 3 sections
# Analzing 32 boards
#      Writing to file NABC141_2501_1_summary.pkl
# Scraping /event/NABC141/25I1/1/summary
# Scrapped a total of 1 sections
# Analzing 34 boards
#      Writing to file NABC141_25I1_1_summary.pkl
# Scraping /event/NABC141/25I2/1/summary
# Scrapped a total of 1 sections
# Analzing 24 boards
#      Writing to file NABC141_25I2_1_summary.pkl
# Scraping /event/NABC141/SS3/4/summary
# Scrapped a total of 2 sections
# Analzing 30 boards
#      Writing to file NABC141_SS3_4_summary.pkl
# Scraping /event/NABC141/SILV/3/summary
# Scrapped a total of 6 sections
# Analzing 26 boards
#      Writing to file NABC141_SILV_3_summary.pkl
# Scraping /event/NABC141/SS3/3/summary
# Scrapped a total of 2 sections
# Analzing 33 boards
#      Writing to file NABC141_SS3_3_summary.pkl
# Scraping /event/NABC141/2402/2/summary
# Scrapped a total of 4 sections
# Analzing 34 boards
#      Writing to file NABC141_2402_2_summary.pkl
# Scraping /event/NABC141/2401/2/summary
# Scrapped a total of 3 sections
# Analzing 33 boards
# Scraping /event/NABC141/2403/2/summary
# Scrapped a total of 4 sections
# Analzing 33 boards
#      Writing to file NABC141_2403_2_summary.pkl
# Scraping /event/NABC141/2405/1/summary
# Scrapped a total of 1 sections
# Analzing 0 boards
# Scraping /event/NABC141/2406/1/summary
# Scrapped a total of 1 sections
# Analzing 0 boards
# Scraping /event/NABC141/24I3/1/summary
# Scrapped a total of 1 sections
# Analzing 26 boards
#      Writing to file NABC141_24I3_1_summary.pkl
# Scraping /event/NABC141/24I4/1/summary
# Scrapped a total of 1 sections
# Analzing 24 boards
#      Writing to file NABC141_24I4_1_summary.pkl
# Scraping /event/NABC141/2402/1/summary
# Scrapped a total of 4 sections
# Analzing 32 boards
#      Writing to file NABC141_2402_1_summary.pkl
# Scraping /event/NABC141/2401/1/summary
# Scrapped a total of 3 sections
# Analzing 33 boards
#      Writing to file NABC141_2401_1_summary.pkl
# Scraping /event/NABC141/24I5/1/summary
# Scrapped a total of 1 sections
# Analzing 33 boards
# Scraping /event/NABC141/2403/1/summary
# Scrapped a total of 4 sections
# Analzing 33 boards
#      Writing to file NABC141_2403_1_summary.pkl
# Scraping /event/NABC141/24I1/1/summary
# Scrapped a total of 1 sections
# Analzing 33 boards
#      Writing to file NABC141_24I1_1_summary.pkl
# Scraping /event/NABC141/24I2/1/summary
# Scrapped a total of 1 sections
# Analzing 28 boards
#      Writing to file NABC141_24I2_1_summary.pkl
# Scraping /event/NABC141/2404/1/summary
# Scrapped a total of 1 sections
# Analzing 28 boards
# Scraping /event/NABC141/SS4/1/summary
# Scrapped a total of 1 sections
# Analzing 34 boards
# Scraping /event/NABC141/2305/2/summary
# Scrapped a total of 2 sections
# Analzing 30 boards
#      Writing to file NABC141_2305_2_summary.pkl
# Scraping /event/NABC141/SILV/2/summary
# Scrapped a total of 11 sections
# Analzing 26 boards
#      Writing to file NABC141_SILV_2_summary.pkl
# Scraping /event/NABC141/SS3/2/summary
# Scrapped a total of 1 sections
# Analzing 28 boards
#      Writing to file NABC141_SS3_2_summary.pkl
# Scraping /event/NABC141/23I9/1/summary
# Scrapped a total of 1 sections
# Analzing 0 boards
# Scraping /event/NABC141/23I1/1/summary
# Scrapped a total of 1 sections
# Analzing 24 boards
#      Writing to file NABC141_23I1_1_summary.pkl
# Scraping /event/NABC141/2301/1/summary
# Scrapped a total of 2 sections
# Analzing 30 boards
#      Writing to file NABC141_2301_1_summary.pkl
# Scraping /event/NABC141/SS2/4/summary
# Scrapped a total of 2 sections
# Analzing 28 boards
# Scraping /event/NABC141/IMPS/4/summary
# Scrapped a total of 6 sections
# Analzing 26 boards
# Scraping /event/NABC141/2202/2/summary
# Scrapped a total of 4 sections
# Analzing 26 boards
# Scraping /event/NABC141/2203/2/summary
# Scrapped a total of 4 sections
# Analzing 30 boards
# Scraping /event/NABC141/22I6/1/summary
# Scrapped a total of 1 sections
# Analzing 30 boards
# Scraping /event/NABC141/SS2/3/summary
# Scrapped a total of 2 sections
# Analzing 30 boards
# Scraping /event/NABC141/IMPS/3/summary
# Scrapped a total of 6 sections
# Analzing 26 boards
# Scraping /event/NABC141/2201/2/summary
# Scrapped a total of 4 sections
# Analzing 33 boards
# Scraping /event/NABC141/22I4/1/summary
# Scrapped a total of 1 sections
# Analzing 32 boards
# Scraping /event/NABC141/22I5/1/summary
# Scrapped a total of 1 sections
# Analzing 24 boards
# Scraping /event/NABC141/2202/1/summary
# Scrapped a total of 4 sections
# Analzing 30 boards
# Scraping /event/NABC141/2203/1/summary
# Scrapped a total of 4 sections
# Analzing 30 boards
# Scraping /event/NABC141/SS1/2/summary
# Scrapped a total of 1 sections
# Analzing 32 boards
#      Writing to file NABC141_SS1_2_summary.pkl
# Scraping /event/NABC141/2301/2/summary
# Scrapped a total of 2 sections
# Analzing 30 boards
#      Writing to file NABC141_2301_2_summary.pkl
# Scraping /event/NABC141/2201/1/summary
# Scrapped a total of 4 sections
# Analzing 33 boards
#      Writing to file NABC141_2201_1_summary.pkl
# Scraping /event/NABC141/22I2/1/summary
# Scrapped a total of 1 sections
# Analzing 24 boards
#      Writing to file NABC141_22I2_1_summary.pkl
# Scraping /event/NABC141/22I1/1/summary
# Scrapped a total of 1 sections
# Analzing 26 boards
#      Writing to file NABC141_22I1_1_summary.pkl
# Scraping /event/NABC141/23I5/1/summary
# Scrapped a total of 1 sections
# Analzing 27 boards
#      Writing to file NABC141_23I5_1_summary.pkl
# Scraping /event/NABC141/23I6/1/summary
# Scrapped a total of 1 sections
# Analzing 24 boards
#      Writing to file NABC141_23I6_1_summary.pkl
# Scraping /event/NABC141/2305/1/summary
# Scrapped a total of 2 sections
# Analzing 30 boards
#      Writing to file NABC141_2305_1_summary.pkl
# Scraping /event/NABC141/SILV/1/summary
# Scrapped a total of 11 sections
# Analzing 26 boards
#      Writing to file NABC141_SILV_1_summary.pkl
# Scraping /event/NABC141/22I3/1/summary
# Scrapped a total of 1 sections
# Analzing 18 boards
#      Writing to file NABC141_22I3_1_summary.pkl
# Scraping /event/NABC141/SS3/1/summary
# Scrapped a total of 1 sections
# Analzing 28 boards
#      Writing to file NABC141_SS3_1_summary.pkl
# Scraping /event/NABC141/2102/2/summary
# Scrapped a total of 2 sections
# Analzing 27 boards
# Scraping /event/NABC141/SS2/2/summary
# Scrapped a total of 1 sections
# Analzing 33 boards
# Scraping /event/NABC141/IMPS/2/summary
# Scrapped a total of 12 sections
# Analzing 26 boards
# Scraping /event/NABC141/21I5/1/summary
# Scrapped a total of 1 sections
# Analzing 36 boards
# Scraping /event/NABC141/2103/1/summary
# Scrapped a total of 1 sections
# Analzing 0 boards
# Scraping /event/NABC141/2101/2/summary
# Scrapped a total of 3 sections
# Analzing 30 boards
# Scraping /event/NABC141/21I3/1/summary
# Scrapped a total of 2 sections
# Analzing 30 boards

# %%
for _ in range(5000):
    write_one_tournament()
# Out:
# Scraping /event/NABC161/18N1/1/summary
# Scrapped a total of 1 sections
# Analzing 27 boards
#      Writing to file NABC161_18N1_1_summary.pkl
# Scraping /event/NABC161/18DA/1/summary
# Scrapped a total of 4 sections
# Analzing 28 boards
#      Writing to file NABC161_18DA_1_summary.pkl
# Scraping /event/NABC161/18DG/1/summary
# Scrapped a total of 5 sections
# Analzing 30 boards
#      Writing to file NABC161_18DG_1_summary.pkl
# Scraping /event/NABC161/OPEN/3/summary
# Scrapped a total of 7 sections
# Analzing 26 boards
#      Writing to file NABC161_OPEN_3_summary.pkl
# Scraping /event/NABC161/OPEN/2/summary
